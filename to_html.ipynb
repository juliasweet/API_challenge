# %%
# Import dependencies
import pandas as pd

# %%
path = "WeatherPy_results07-11-2019_JS.csv"

# %%
results = pd.read_csv(path)

# %%
results.head()
# Out:
#    Unnamed: 0           City Cloudiness Country        Date Humidity Latitude  \
# 0           0          Yumen         0%      CN  2019-07-11      24%   40.29°
# 1           1      Quisqueya        40%      DO  2019-07-11      62%   18.55°
# 2           2        Aklavik        75%      CA  2019-07-11      57%   68.22°
# 3           3  Mar del Plata         0%      AR  2019-07-11      66%  -46.43°
# 4           4      Busselton        78%      AU  2019-07-11      78%  -33.64°
#
#   Longitude Maximum Temperature Wind Speed
# 0    97.04°             75.83°F   5.84 mph
# 1   -69.41°              87.8°F   5.82 mph
# 2  -135.01°              51.8°F  13.87 mph
# 3   -67.52°             41.09°F   6.04 mph
# 4   115.35°              45.0°F   8.77 mph

# %%
DF = pd.DataFrame(results)

# %%
DF.head()
# Out:
#    Unnamed: 0           City Cloudiness Country        Date Humidity Latitude  \
# 0           0          Yumen         0%      CN  2019-07-11      24%   40.29°
# 1           1      Quisqueya        40%      DO  2019-07-11      62%   18.55°
# 2           2        Aklavik        75%      CA  2019-07-11      57%   68.22°
# 3           3  Mar del Plata         0%      AR  2019-07-11      66%  -46.43°
# 4           4      Busselton        78%      AU  2019-07-11      78%  -33.64°
#
#   Longitude Maximum Temperature Wind Speed
# 0    97.04°             75.83°F   5.84 mph
# 1   -69.41°              87.8°F   5.82 mph
# 2  -135.01°              51.8°F  13.87 mph
# 3   -67.52°             41.09°F   6.04 mph
# 4   115.35°              45.0°F   8.77 mph

# %%
list(DF.columns)
# Out:
# ['Unnamed: 0',
#  'City',
#  'Cloudiness',
#  'Country',
#  'Date',
#  'Humidity',
#  'Latitude',
#  'Longitude',
#  'Maximum Temperature',
#  'Wind Speed']

# %%
DF.set_index("City")
# Out:
#                      Unnamed: 0 Cloudiness Country        Date Humidity  \
# City
# Yumen                         0         0%      CN  2019-07-11      24%
# Quisqueya                     1        40%      DO  2019-07-11      62%
# Aklavik                       2        75%      CA  2019-07-11      57%
# Mar del Plata                 3         0%      AR  2019-07-11      66%
# Busselton                     4        78%      AU  2019-07-11      78%
# Renqiu                        5         0%      CN  2019-07-11      43%
# Hobart                        6        75%      AU  2019-07-11      70%
# Lebu                          7        75%      ET  2019-07-11      87%
# Koumra                        8        96%      TD  2019-07-11      95%
# Havre-Saint-Pierre            9        20%      CA  2019-07-11      67%
# Port Keats                   10        38%      AU  2019-07-11      53%
# Punta Arenas                 11        90%      CL  2019-07-11      86%
# ...

# %%
DF.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
DF.head()
# Out:
#             City Cloudiness Country        Date Humidity Latitude Longitude  \
# 0          Yumen         0%      CN  2019-07-11      24%   40.29°    97.04°
# 1      Quisqueya        40%      DO  2019-07-11      62%   18.55°   -69.41°
# 2        Aklavik        75%      CA  2019-07-11      57%   68.22°  -135.01°
# 3  Mar del Plata         0%      AR  2019-07-11      66%  -46.43°   -67.52°
# 4      Busselton        78%      AU  2019-07-11      78%  -33.64°   115.35°
#
#   Maximum Temperature Wind Speed
# 0             75.83°F   5.84 mph
# 1              87.8°F   5.82 mph
# 2              51.8°F  13.87 mph
# 3             41.09°F   6.04 mph
# 4              45.0°F   8.77 mph

# %%
DF.set_index("City", inplace=True)

# %%
DF.head()
# Out:
#               Cloudiness Country        Date Humidity Latitude Longitude  \
# City
# Yumen                 0%      CN  2019-07-11      24%   40.29°    97.04°
# Quisqueya            40%      DO  2019-07-11      62%   18.55°   -69.41°
# Aklavik              75%      CA  2019-07-11      57%   68.22°  -135.01°
# Mar del Plata         0%      AR  2019-07-11      66%  -46.43°   -67.52°
# Busselton            78%      AU  2019-07-11      78%  -33.64°   115.35°
#
#               Maximum Temperature Wind Speed
# City
# Yumen                     75.83°F   5.84 mph
# Quisqueya                  87.8°F   5.82 mph
# Aklavik                    51.8°F  13.87 mph
# Mar del Plata             41.09°F   6.04 mph
# Busselton                  45.0°F   8.77 mph

# %%
DF.to_html("WeatherData.html")
