# %% [markdown]
# # WeatherPy by Julia Sweet
# ----
#
# #### Commentary
# * This project yielded interesting information about not only weather patterns but also weather reporting, the distribution of cities across the geocoordinate system, and limitations of focusing on city data when attempting to draw conclusions about global weather patterns. See analysis in markdown cells.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import time


#Set today
today=datetime.datetime.today()
today=today.strftime('%m-%d-%Y')
print(f"Code run today, {today}.")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Code run today, 07-11-2019.

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

cities_found=len(cities)
success_rate=cities_found/1500

print(f"{cities_found} geocoordinate pairs of 1500 were near cities with populations of 500 or more.")
print("That's a match rate of " + "{:.2%}".format(success_rate))
# Out:
# 642 geocoordinate pairs of 1500 were near cities with populations of 500 or more.
# That's a match rate of 42.80%

# %% [markdown]
# ## Analysis 1:
#
# After running this several times, I noticed that the number of geocoordinate pairs that were near cities was usually around 40% (+/- about 2%). This tells me that much of the world is not near cities with populations of over 500.
#
# In looking at my charts, I can also see that there is typically more data for cities in the northern hemisphere; that tells me that there are typically more cities with populations of over 500 in the northern hemisphere than there are in the southern hemisphere. Additionally, there are fewer points plotted at the upper and lower ends of each chart, which tells me that there are fewer such cities the closer you move to the poles.

# %%
# Create URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units="imperial"

# %%
#Make empty lists to hold your data.

city_name = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country=[]
date=[]


#Set record number as 1
record = 1

#Set set as 1
QuerySet = 1 


#Set loop
#Go get some fruit to snack on while this runs; you probably have time. 
#As you know, time flies like an arrow; fruit flies like a banana. 
print("Finding information")

for city in cities:
    try:
        query_url = f"{base_url}appid={api_key}&units={units}&q="
        response=requests.get(query_url+city).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        cityname=response["name"]
        print(f"Processing Record #{record}| City: {cityname}")
        print(f" Source URL: {query_url}&q={city}")
        record = record + 1
        
    except:
        print("Your data is in another city. Nevermind; excelsior!")
    continue

    #Make multiple API calls
    if record == 51:
        sleep(10)
        record = 1
        QuerySet= QuerySet + 1
# Out:
# Finding information
# Processing Record #1| City: Yumen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yumen
# Processing Record #2| City: Quisqueya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=quisqueya
# Processing Record #3| City: Aklavik
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aklavik
# Your data is in another city. Nevermind; excelsior!
# Processing Record #4| City: Mar del Plata
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mar del plata
# Processing Record #5| City: Busselton
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=busselton
# Processing Record #6| City: Renqiu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=renqiu
# Processing Record #7| City: Hobart
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hobart
# Processing Record #8| City: Lebu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lebu
# Processing Record #9| City: Koumra
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=koumra
# Processing Record #10| City: Havre-Saint-Pierre
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=havre-saint-pierre
# Your data is in another city. Nevermind; excelsior!
# Processing Record #11| City: Port Keats
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port keats
# Processing Record #12| City: Punta Arenas
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=punta arenas
# Processing Record #13| City: Yellowknife
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yellowknife
# Your data is in another city. Nevermind; excelsior!
# Processing Record #14| City: Nioro
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nioro
# Processing Record #15| City: Rikitea
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=rikitea
# Processing Record #16| City: San Patricio
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=san patricio
# Processing Record #17| City: Atuona
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=atuona
# Processing Record #18| City: Ushuaia
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ushuaia
# Processing Record #19| City: Norman Wells
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=norman wells
# Processing Record #20| City: Jamestown
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=jamestown
# Processing Record #21| City: Alofi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=alofi
# Processing Record #22| City: Khatanga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=khatanga
# Processing Record #23| City: Chuy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=chuy
# Processing Record #24| City: Port Alfred
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port alfred
# Processing Record #25| City: Thompson
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=thompson
# Processing Record #26| City: Bredasdorp
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bredasdorp
# Processing Record #27| City: Port-Gentil
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port-gentil
# Processing Record #28| City: Vao
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vao
# Processing Record #29| City: Mandalgovi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mandalgovi
# Your data is in another city. Nevermind; excelsior!
# Processing Record #30| City: Fujin
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=fujin
# Processing Record #31| City: Puerto Ayora
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=puerto ayora
# Processing Record #32| City: Lismore
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lismore
# Processing Record #33| City: Kosh-Agach
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kosh-agach
# Processing Record #34| City: Port Elizabeth
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port elizabeth
# Processing Record #35| City: Harer
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=harer
# Processing Record #36| City: Baherden
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=baherden
# Processing Record #37| City: Vestmannaeyjar
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vestmannaeyjar
# Processing Record #38| City: Hay River
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hay river
# Processing Record #39| City: Arman
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=arman
# Processing Record #40| City: Graham
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=graham
# Processing Record #41| City: Guozhen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=guozhen
# Processing Record #42| City: Laguna
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=laguna
# Your data is in another city. Nevermind; excelsior!
# Your data is in another city. Nevermind; excelsior!
# Processing Record #43| City: Toktogul
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=toktogul
# Processing Record #44| City: Omboue
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=omboue
# Processing Record #45| City: Bilibino
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bilibino
# Processing Record #46| City: Tiksi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tiksi
# Processing Record #47| City: Tura
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tura
# Processing Record #48| City: Lompoc
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lompoc
# Processing Record #49| City: Melfi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=melfi
# Processing Record #50| City: Hammerfest
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hammerfest
# Processing Record #51| City: Vardo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vardo
# Processing Record #52| City: Kapaa
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kapaa
# Processing Record #53| City: Iskateley
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=iskateley
# Your data is in another city. Nevermind; excelsior!
# Processing Record #54| City: Nalut
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nalut
# Processing Record #55| City: Vaini
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vaini
# Processing Record #56| City: Waihi Beach
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=waihi beach
# Processing Record #57| City: Renfrew
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=renfrew
# Processing Record #58| City: Villa Carlos Paz
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=villa carlos paz
# Processing Record #59| City: San Matias
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=san matias
# Processing Record #60| City: Rawson
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=rawson
# Processing Record #61| City: Carnarvon
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=carnarvon
# Processing Record #62| City: Yatou
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yatou
# Processing Record #63| City: Albany
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=albany
# Processing Record #64| City: Te Anau
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=te anau
# Processing Record #65| City: East London
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=east london
# Processing Record #66| City: Kolosovka
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kolosovka
# Processing Record #67| City: Flinders
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=flinders
# Processing Record #68| City: Nikolskoye
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nikolskoye
# Processing Record #69| City: Bluff
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bluff
# Your data is in another city. Nevermind; excelsior!
# Processing Record #70| City: Hithadhoo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hithadhoo
# Processing Record #71| City: Bathsheba
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bathsheba
# Processing Record #72| City: Ilulissat
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ilulissat
# Processing Record #73| City: Upernavik
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=upernavik
# Processing Record #74| City: Fairbanks
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=fairbanks
# Processing Record #75| City: Lorengau
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lorengau
# Your data is in another city. Nevermind; excelsior!
# Processing Record #76| City: Saint George
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=saint george
# Processing Record #77| City: Broken Hill
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=broken hill
# Your data is in another city. Nevermind; excelsior!
# Processing Record #78| City: Sakharovo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sakharovo
# Processing Record #79| City: Tasiilaq
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tasiilaq
# Processing Record #80| City: Baker City
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=baker city
# Processing Record #81| City: La Ronge
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=la ronge
# Processing Record #82| City: Tambo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tambo
# Processing Record #83| City: Geraldton
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=geraldton
# Processing Record #84| City: Jilib
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=jilib
# Processing Record #85| City: Georgetown
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=georgetown
# Processing Record #86| City: Mataura
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mataura
# Processing Record #87| City: Yilan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yilan
# Processing Record #88| City: Wonthaggi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=wonthaggi
# Processing Record #89| City: Tecoanapa
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tecoanapa
# Processing Record #90| City: Butaritari
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=butaritari
# Processing Record #91| City: Salalah
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=salalah
# Processing Record #92| City: Cabo San Lucas
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=cabo san lucas
# Processing Record #93| City: Lata
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lata
# Your data is in another city. Nevermind; excelsior!
# Your data is in another city. Nevermind; excelsior!
# Processing Record #94| City: Dikson
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dikson
# Processing Record #95| City: Paamiut
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=paamiut
# Processing Record #96| City: Yalova
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yalova
# Processing Record #97| City: Baykit
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=baykit
# Processing Record #98| City: Samfya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=samfya
# Processing Record #99| City: Tondano
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tondano
# Processing Record #100| City: Cidreira
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=cidreira
# Processing Record #101| City: Marfino
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=marfino
# Processing Record #102| City: Bethel
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bethel
# Your data is in another city. Nevermind; excelsior!
# Processing Record #103| City: Loreto
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=loreto
# Processing Record #104| City: Constitucion
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=constitucion
# Processing Record #105| City: Portland
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=portland
# Processing Record #106| City: Ngunguru
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ngunguru
# Processing Record #107| City: Cape Town
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=cape town
# Processing Record #108| City: Isangel
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=isangel
# Processing Record #109| City: Macusani
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=macusani
# Processing Record #110| City: Gat
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=gat
# Processing Record #111| City: Altay
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=altay
# Your data is in another city. Nevermind; excelsior!
# Processing Record #112| City: Hilo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hilo
# Processing Record #113| City: Moose Factory
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=moose factory
# Processing Record #114| City: Nizhniy Ingash
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nizhniy ingash
# Processing Record #115| City: San Cristobal
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=san cristobal
# Processing Record #116| City: Dingle
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dingle
# Your data is in another city. Nevermind; excelsior!
# Processing Record #117| City: Buta
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=buta
# Processing Record #118| City: Verkhnyaya Toyma
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=verkhnyaya toyma
# Processing Record #119| City: Saint-Philippe
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=saint-philippe
# Processing Record #120| City: Avarua
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=avarua
# Processing Record #121| City: Huanren
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=huanren
# Processing Record #122| City: Nipawin
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nipawin
# Processing Record #123| City: Tigil
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tigil
# Processing Record #124| City: Samarai
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=samarai
# Processing Record #125| City: Gunjur
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=gunjur
# Processing Record #126| City: Ribeira Grande
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ribeira grande
# Processing Record #127| City: Terrace
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=terrace
# Processing Record #128| City: Los Llanos de Aridane
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=los llanos de aridane
# Your data is in another city. Nevermind; excelsior!
# Processing Record #129| City: Neuenkirch
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=neuenkirch
# Processing Record #130| City: Rocha
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=rocha
# Your data is in another city. Nevermind; excelsior!
# Processing Record #131| City: Kaseda
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kaseda
# Processing Record #132| City: Zhigansk
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=zhigansk
# Processing Record #133| City: Port Macquarie
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port macquarie
# Processing Record #134| City: Belyy Yar
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=belyy yar
# Your data is in another city. Nevermind; excelsior!
# Processing Record #135| City: Thunder Bay
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=thunder bay
# Processing Record #136| City: Katsuura
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=katsuura
# Processing Record #137| City: Namibe
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=namibe
# Processing Record #138| City: Klaksvik
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=klaksvik
# Processing Record #139| City: Leningradskiy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=leningradskiy
# Processing Record #140| City: Srednekolymsk
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=srednekolymsk
# Processing Record #141| City: Port-Cartier
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port-cartier
# Processing Record #142| City: Carlow
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=carlow
# Processing Record #143| City: Victoria
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=victoria
# Processing Record #144| City: Erenhot
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=erenhot
# Processing Record #145| City: Ruteng
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ruteng
# Your data is in another city. Nevermind; excelsior!
# Processing Record #146| City: Mount Isa
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mount isa
# Processing Record #147| City: Springfield
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=springfield
# Processing Record #148| City: Zhoucun
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=zhoucun
# Processing Record #149| City: Tallahassee
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tallahassee
# Processing Record #150| City: Batagay-Alyta
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=batagay-alyta
# Your data is in another city. Nevermind; excelsior!
# Processing Record #151| City: Biltine
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=biltine
# Processing Record #152| City: Maumere
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=maumere
# Processing Record #153| City: Nouakchott
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nouakchott
# Processing Record #154| City: Wagar
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=wagar
# Processing Record #155| City: Tuktoyaktuk
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tuktoyaktuk
# Your data is in another city. Nevermind; excelsior!
# Processing Record #156| City: Darhan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=darhan
# Processing Record #157| City: Ahipara
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ahipara
# Processing Record #158| City: Coahuayana
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=coahuayana
# Your data is in another city. Nevermind; excelsior!
# Processing Record #159| City: Loa Janan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=loa janan
# Processing Record #160| City: Kokoda
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kokoda
# Processing Record #161| City: Churapcha
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=churapcha
# Processing Record #162| City: Beyneu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=beyneu
# Processing Record #163| City: Ampanihy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ampanihy
# Your data is in another city. Nevermind; excelsior!
# Processing Record #164| City: Marawi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=marawi
# Processing Record #165| City: Arraial do Cabo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=arraial do cabo
# Processing Record #166| City: Lavrentiya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lavrentiya
# Processing Record #167| City: Viedma
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=viedma
# Processing Record #168| City: Aguas Formosas
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aguas formosas
# Processing Record #169| City: Dalianwan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dalianwan
# Processing Record #170| City: Grindavik
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=grindavik
# Processing Record #171| City: Ulety
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ulety
# Processing Record #172| City: Elban
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=elban
# Your data is in another city. Nevermind; excelsior!
# Processing Record #173| City: Severo-Kurilsk
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=severo-kurilsk
# Processing Record #174| City: Tigard
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tigard
# Processing Record #175| City: Vidim
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vidim
# Processing Record #176| City: Touros
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=touros
# Your data is in another city. Nevermind; excelsior!
# Processing Record #177| City: Clyde River
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=clyde river
# Processing Record #178| City: Bambous Virieux
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bambous virieux
# Processing Record #179| City: Mahebourg
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mahebourg
# Processing Record #180| City: Pevek
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pevek
# Processing Record #181| City: Dunedin
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dunedin
# Processing Record #182| City: Husavik
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=husavik
# Processing Record #183| City: Mitu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mitu
# Processing Record #184| City: Pudozh
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pudozh
# Processing Record #185| City: Yinchuan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yinchuan
# Processing Record #186| City: Alihe
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=alihe
# Processing Record #187| City: Kaitangata
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kaitangata
# Processing Record #188| City: Westport
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=westport
# Processing Record #189| City: Alugan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=alugan
# Processing Record #190| City: Chara
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=chara
# Processing Record #191| City: Kodiak
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kodiak
# Processing Record #192| City: Qaanaaq
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=qaanaaq
# Processing Record #193| City: Airai
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=airai
# Processing Record #194| City: Peterhead
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=peterhead
# Your data is in another city. Nevermind; excelsior!
# Processing Record #195| City: Ballachulish
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ballachulish
# Processing Record #196| City: Yarmouth
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yarmouth
# Your data is in another city. Nevermind; excelsior!
# Processing Record #197| City: Kisangani
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kisangani
# Processing Record #198| City: Aldan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aldan
# Processing Record #199| City: Kattivakkam
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kattivakkam
# Your data is in another city. Nevermind; excelsior!
# Processing Record #200| City: Brownsville
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=brownsville
# Your data is in another city. Nevermind; excelsior!
# Processing Record #201| City: Russell
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=russell
# Processing Record #202| City: Vila Velha
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vila velha
# Processing Record #203| City: Kruisfontein
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kruisfontein
# Processing Record #204| City: Hermanus
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hermanus
# Processing Record #205| City: Esperance
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=esperance
# Processing Record #206| City: Kenai
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kenai
# Processing Record #207| City: Fort Morgan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=fort morgan
# Your data is in another city. Nevermind; excelsior!
# Processing Record #208| City: Provideniya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=provideniya
# Processing Record #209| City: Sobolevo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sobolevo
# Processing Record #210| City: Kumluca
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kumluca
# Processing Record #211| City: Champua
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=champua
# Processing Record #212| City: Buin
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=buin
# Processing Record #213| City: Solnechnyy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=solnechnyy
# Processing Record #214| City: Blagoyevo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=blagoyevo
# Processing Record #215| City: Weligama
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=weligama
# Processing Record #216| City: Johor Bahru
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=johor bahru
# Processing Record #217| City: Port Blair
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=port blair
# Processing Record #218| City: Kjollefjord
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kjollefjord
# Processing Record #219| City: Krasnoshchekovo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=krasnoshchekovo
# Your data is in another city. Nevermind; excelsior!
# Processing Record #220| City: Alyangula
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=alyangula
# Your data is in another city. Nevermind; excelsior!
# Processing Record #221| City: Mayumba
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mayumba
# Processing Record #222| City: Marzuq
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=marzuq
# Processing Record #223| City: Hofn
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hofn
# Processing Record #224| City: Narsaq
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=narsaq
# Processing Record #225| City: Safford
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=safford
# Processing Record #226| City: Bukama
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bukama
# Processing Record #227| City: Gaogou
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=gaogou
# Processing Record #228| City: Kununurra
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kununurra
# Processing Record #229| City: Berezna
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=berezna
# Processing Record #230| City: Maloy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=maloy
# Processing Record #231| City: Timra
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=timra
# Processing Record #232| City: Longyearbyen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=longyearbyen
# Processing Record #233| City: Don Sak
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=don sak
# Processing Record #234| City: Barrow
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=barrow
# Processing Record #235| City: Mehamn
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mehamn
# Processing Record #236| City: Talnakh
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=talnakh
# Processing Record #237| City: Sumkino
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sumkino
# Processing Record #238| City: Gusau
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=gusau
# Processing Record #239| City: Muros
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=muros
# Processing Record #240| City: Krasnoye
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=krasnoye
# Processing Record #241| City: Saskylakh
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=saskylakh
# Processing Record #242| City: Wodonga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=wodonga
# Processing Record #243| City: Bo Phloi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bo phloi
# Processing Record #244| City: Labuhan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=labuhan
# Processing Record #245| City: Basqal
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=basqal
# Processing Record #246| City: Vozhega
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vozhega
# Processing Record #247| City: Manjeshwar
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=manjeshwar
# Processing Record #248| City: Sao Joao da Barra
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sao joao da barra
# Processing Record #249| City: Victor Harbor
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=victor harbor
# Processing Record #250| City: Valera
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=valera
# Processing Record #251| City: Auki
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=auki
# Processing Record #252| City: Nouadhibou
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nouadhibou
# Processing Record #253| City: Putina
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=putina
# Processing Record #254| City: Faya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=faya
# Processing Record #255| City: Mvuma
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mvuma
# Your data is in another city. Nevermind; excelsior!
# Processing Record #256| City: Eureka
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=eureka
# Processing Record #257| City: Qostanay
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=qostanay
# Processing Record #258| City: Paulista
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=paulista
# Processing Record #259| City: Hervey Bay
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hervey bay
# Processing Record #260| City: Torbay
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=torbay
# Processing Record #261| City: Skibbereen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=skibbereen
# Processing Record #262| City: Llanes
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=llanes
# Processing Record #263| City: Dire
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dire
# Processing Record #264| City: Dogondoutchi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=dogondoutchi
# Processing Record #265| City: Puksoozero
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=puksoozero
# Processing Record #266| City: Ketchikan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ketchikan
# Your data is in another city. Nevermind; excelsior!
# Processing Record #267| City: Hamilton
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hamilton
# Processing Record #268| City: Karimganj
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=karimganj
# Processing Record #269| City: Faanui
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=faanui
# Processing Record #270| City: New Norfolk
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=new norfolk
# Processing Record #271| City: Kavieng
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kavieng
# Processing Record #272| City: Ancud
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ancud
# Processing Record #273| City: Khonsa
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=khonsa
# Processing Record #274| City: Miri
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=miri
# Your data is in another city. Nevermind; excelsior!
# Processing Record #275| City: Maceio
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=maceio
# Processing Record #276| City: Berberati
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=berberati
# Your data is in another city. Nevermind; excelsior!
# Processing Record #277| City: Lubao
# ...
# Processing Record #481| City: Sorong
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sorong
# Processing Record #482| City: Yeppoon
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yeppoon
# Processing Record #483| City: Belmonte
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=belmonte
# Processing Record #484| City: Larap
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=larap
# Your data is in another city. Nevermind; excelsior!
# Processing Record #485| City: Lufilufi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lufilufi
# Processing Record #486| City: Diapaga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=diapaga
# Processing Record #487| City: Taganak
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=taganak
# Processing Record #488| City: Magadan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=magadan
# Your data is in another city. Nevermind; excelsior!
# Processing Record #489| City: Muisne
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=muisne
# Processing Record #490| City: Lubango
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=lubango
# Your data is in another city. Nevermind; excelsior!
# Your data is in another city. Nevermind; excelsior!
# Processing Record #491| City: Katobu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=katobu
# Processing Record #492| City: Wanning
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=wanning
# Processing Record #493| City: Kahului
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kahului
# Processing Record #494| City: Imeni Poliny Osipenko
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=imeni poliny osipenko
# Processing Record #495| City: Bundaberg
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bundaberg
# Processing Record #496| City: Mongo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mongo
# Processing Record #497| City: Comodoro Rivadavia
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=comodoro rivadavia
# Processing Record #498| City: Petawawa
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=petawawa
# Processing Record #499| City: Cayenne
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=cayenne
# Processing Record #500| City: Kysyl-Syr
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kysyl-syr
# Processing Record #501| City: Mahajanga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mahajanga
# Your data is in another city. Nevermind; excelsior!
# Processing Record #502| City: Sur
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sur
# Processing Record #503| City: Mwinilunga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mwinilunga
# Processing Record #504| City: Terme
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=terme
# Your data is in another city. Nevermind; excelsior!
# Processing Record #505| City: Namasuba
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=namasuba
# Your data is in another city. Nevermind; excelsior!
# Processing Record #506| City: Sabang
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sabang
# Processing Record #507| City: Aksarka
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aksarka
# Processing Record #508| City: Baijiantan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=baijiantan
# Processing Record #509| City: Kapiri Mposhi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kapiri mposhi
# Processing Record #510| City: Naze
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=naze
# Processing Record #511| City: Mountain Home
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mountain home
# Processing Record #512| City: Ponta Delgada
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ponta delgada
# Processing Record #513| City: Teya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=teya
# Your data is in another city. Nevermind; excelsior!
# Processing Record #514| City: Hongjiang
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=hongjiang
# Processing Record #515| City: Johnson City
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=johnson city
# Processing Record #516| City: Qaqortoq
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=qaqortoq
# Processing Record #517| City: Ituporanga
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ituporanga
# Processing Record #518| City: Waingapu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=waingapu
# Your data is in another city. Nevermind; excelsior!
# Processing Record #519| City: Nishihara
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nishihara
# Processing Record #520| City: Yaan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yaan
# Processing Record #521| City: Piacabucu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=piacabucu
# Processing Record #522| City: Bonoua
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bonoua
# Processing Record #523| City: Rio Gallegos
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=rio gallegos
# Processing Record #524| City: Wuwei
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=wuwei
# Processing Record #525| City: Aswan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aswan
# Processing Record #526| City: Rantepao
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=rantepao
# Processing Record #527| City: Masuguru
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=masuguru
# Processing Record #528| City: Villanueva de Cordoba
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=villanueva de cordoba
# Processing Record #529| City: Nhulunbuy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nhulunbuy
# Your data is in another city. Nevermind; excelsior!
# Processing Record #530| City: Karratha
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=karratha
# Processing Record #531| City: Vanimo
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=vanimo
# Processing Record #532| City: Osasco
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=osasco
# Processing Record #533| City: Humaita
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=humaita
# Processing Record #534| City: Necochea
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=necochea
# Processing Record #535| City: Kastamonu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kastamonu
# Processing Record #536| City: Nenjiang
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nenjiang
# Processing Record #537| City: Kuito
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kuito
# Processing Record #538| City: Ilhabela
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ilhabela
# Processing Record #539| City: Ardalstangen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ardalstangen
# Processing Record #540| City: Orange Cove
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=orange cove
# Processing Record #541| City: Ritchie
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ritchie
# Your data is in another city. Nevermind; excelsior!
# Processing Record #542| City: Tautira
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tautira
# Processing Record #543| City: Sorland
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sorland
# Processing Record #544| City: Ozinki
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=ozinki
# Processing Record #545| City: Kobryn
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kobryn
# Processing Record #546| City: Antanifotsy
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=antanifotsy
# Processing Record #547| City: Maningrida
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=maningrida
# Processing Record #548| City: Tinglev
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=tinglev
# Your data is in another city. Nevermind; excelsior!
# Processing Record #549| City: Yerbogachen
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=yerbogachen
# Processing Record #550| City: Buala
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=buala
# Processing Record #551| City: Luganville
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=luganville
# Processing Record #552| City: Manta
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=manta
# Processing Record #553| City: Praya
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=praya
# Processing Record #554| City: Berdychiv
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=berdychiv
# Processing Record #555| City: Pedasi
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pedasi
# Processing Record #556| City: Damietta
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=damietta
# Processing Record #557| City: Pathein
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pathein
# Processing Record #558| City: Cazzago San Martino
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=cazzago san martino
# Processing Record #559| City: Nueva Gerona
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nueva gerona
# Processing Record #560| City: Pochutla
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pochutla
# Processing Record #561| City: Fortuna
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=fortuna
# Processing Record #562| City: Nemuro
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=nemuro
# Processing Record #563| City: Mbigou
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=mbigou
# Processing Record #564| City: Campbell River
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=campbell river
# Processing Record #565| City: Northam
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=northam
# Processing Record #566| City: Sinnamary
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=sinnamary
# Processing Record #567| City: Kathu
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kathu
# Processing Record #568| City: Kharan
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=kharan
# Processing Record #569| City: Aykhal
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=aykhal
# Processing Record #570| City: Bom Jesus
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=bom jesus
# Your data is in another city. Nevermind; excelsior!
# Your data is in another city. Nevermind; excelsior!
# Processing Record #571| City: Pierre
#  Source URL: http://api.openweathermap.org/data/2.5/weather?appid=1100f5659b71a57732359722cc46bbd5&units=imperial&q=&q=pierre

# %%
# Make this puppy into a dictionary
weather_dictionary={
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity, 
    "Latitude": latitude,
    "Longitude": longitude,
    "Maximum Temperature": max_temperature,
    "Wind Speed": wind_speed
}

#Make the dictionary into a DataFrame; format values

weather_df=pd.DataFrame(weather_dictionary)
weather_df["Cloudiness"]=weather_df["Cloudiness"].map("{:}%".format)
weather_df["Date"]=pd.to_datetime(weather_df["Date"], unit='s')
weather_df['Date'] = weather_df['Date'].dt.date
weather_df["Humidity"]=weather_df["Humidity"].map("{:}%".format)
weather_df["Maximum Temperature"]=weather_df["Maximum Temperature"].map("{:}°F".format)
weather_df["Wind Speed"]=weather_df["Wind Speed"].map("{:} mph".format)
weather_df["Latitude"]=weather_df["Latitude"].map("{:}°".format)
weather_df["Longitude"]=weather_df["Longitude"].map("{:}°".format)
weather_df
#Save the DataFrame as a csv file for posterity
weather_df.to_csv(f"WeatherPy_results{today}_JS.csv")

number_cities = len(weather_df["City"])
print(f"We found data for {number_cities} cities.")
weather_df.head()
# Out:
# We found data for 571 cities.
#             City Cloudiness Country        Date Humidity Latitude Longitude  \
# 0          Yumen         0%      CN  2019-07-11      24%   40.29°    97.04°
# 1      Quisqueya        40%      DO  2019-07-11      62%   18.55°   -69.41°
# 2        Aklavik        75%      CA  2019-07-11      57%   68.22°  -135.01°
# 3  Mar del Plata         0%      AR  2019-07-11      66%  -46.43°   -67.52°
# 4      Busselton        78%      AU  2019-07-11      78%  -33.64°   115.35°
#
#   Maximum Temperature Wind Speed
# 0             75.83°F   5.84 mph
# 1              87.8°F   5.82 mph
# 2              51.8°F  13.87 mph
# 3             41.09°F   6.04 mph
# 4              45.0°F   8.77 mph

# %% [markdown]
# ## Analysis 1.b
#
# Another trend that emerged is that weather data does not exist for all of the cities that matched with geocoordinate pairs. This outcome was somewhat less common; about 90% of the cities did have weather data.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Create a scatter plot
#Set latitude as X axis and Max Temperature as Y axis
plt.ylim(-5, 120)
plt.scatter(latitude, max_temperature, marker="o", facecolors="red", edgecolors="black",s=50, alpha=0.75)

#Add clarifying elements:
#Title
plt.title(f"City Latitude vs. Temperature (in F) for {today}")
plt.xlabel("City Latitude")
plt.ylabel("Temperature (in F)")
#Axis labels

#Gridlines
plt.grid(True)
#Save it
plt.savefig(f"LatitudevsTemperature{today}_JS.png")

plt.show()

# %% [markdown]
# ## Analysis 2:
#
# The data consistently show a curve with its apex skewed slightly north of the equator. This makes sense given that it is currently summer in the northern hemisphere. The subsolar point, or point closest to the sun in a direct line, is north of the equator. The variation among the points along the curve can be explained by time of day, elevation, and other weather elements (see below).

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Create a scatter plot
#Create a scatter plot
#Set latitude as X axis and humidity as Y axis
plt.ylim(-5, 105) #Json data had an issue and returned humidity levels of >100%
plt.scatter(latitude, humidity, marker="o", facecolors="goldenrod", edgecolors="black",s=50, alpha=0.75)

#Gridlines
plt.grid(True)
#Add clarifying elements:
#Title
plt.title(f"City Latitude vs. Humidity (%) for {today}")
plt.xlabel("City Latitude")
plt.ylabel("Percent Humidity")

plt.savefig(f"LatitudevsHumidity{today}_JS.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Analysis 3:
#
# With the exception of a few weather reports that clearly had typos (humidity levels of nearly 300%), the data were fairly consistent: humidity levels of less than 60% were relatively rare overall and were slightly more rare in the southern hemisphere. This effect became more pronounced the father south of the equator a city was. This is likely due to a combination of factors (seasonal differences and relativlely small number of cities with populations of 500 or more in the southern hemisphere).

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Create a scatter plot
#Create a scatter plot
#Set latitude as X axis and Max Temperature as Y axis
plt.scatter(latitude, cloudiness, marker="o", facecolors="dimgray", edgecolors="black",s=50, alpha=0.5)

#Gridlines
plt.grid(True)
#Add clarifying elements:
#Title
plt.title("City Latitude vs. Cloudiness (%) for {today}")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig(f"LatitudevsCloudiness{today}_JS.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Analysis 4:
#
# This particular chart reveals a bit less about weather and a bit more about the way that we measure and report it. In the bulk of data sets that I examined, there were high concentrations of cloudiness at even intervals. This tells me that although a percentage is quantitative, the number reported is not necessarily precise. It seems likely that most weather reports include cloud cover numbers that are rounded to the nearest 5% or 10%.
#
# That said, many of the charts revealed slightly more instances of cloudiness in the northern hemisphere and a bit fewer in the southern hemisphere.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Create a scatter plot
#Set latitude as X axis and Wind Speed as Y axis
plt.scatter(latitude, wind_speed, marker="o", facecolors="aquamarine", edgecolors="black",s=50, alpha=0.75)

#Gridlines
plt.grid(True)
#Add clarifying elements:
#Title
plt.title(f"City Latitude vs. Wind Speed (%) for {today}")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig(f"LatitudevsWindSpeed{today}_JS.png")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Analysis 5:
#
# This chart primarily revealed that high wind speeds (over 25 miles an hour) are rare in cities that have more than 500 people. The vast majority of wind speeds are below 10 mph, and the number of instances of a particular speed decreases as the speed increases.
